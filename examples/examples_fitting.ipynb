# %% [markdown]
# # Examples for DA fitting
#
# This notebook gives an overview of python functions implemented for the analysis of dynamic aperture data from SixDesk.
#
# ## Initialize

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sixdesk.da import *

# %% [markdown]
# # Dynamic aperture vs. turn from SixDeskDB
#
# The functionality for the fitting is provided by the davst class in the sixdesk module.
#
# ## Plot the DA vs. turn Data from SixDeskDB

# %%
a = davst('/home/phermes/development/SixDeskDB/chromB2_QP_0_OC_0.db')

# %%
a.plot_simulated_davst(seed=5)
plt.ylim(14.8,15.1)
plt.show()

# %% [markdown]
# ## Perform the fitting for one seed
# Fit the data and get back the fit parameters

# %%
_,d,b,k,exda = a.fit_single_seed(-5,5,0.5,5)

# %% [markdown]
# Plot the data together with the fit

# %%
x = np.arange(100,100000,100)
plt.plot(x,a.dafunction(x,d,b,k),label='Data')
a.plot_simulated_davst(seed=5)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Plot data and fit for 30 minutes (20241900 turns)

# %%
x = np.arange(100,20241900,100)
plt.plot(x,a.dafunction(x,d,b,k),label='Data')
a.plot_simulated_davst(seed=5)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Perform the fitting for all seeds

# %%
a  = davst('/home/phermes/development/SixDeskDB/chromB2_QP_2_OC_0.db')
df = a.fitda(1,10,0.5,steps=1,verbose=False)

# %% [markdown]
# We get back a table including the fit parameters for the individual seeds

# %%
df.head()
# Out:
#    seed          d         b    k       exda
# 0     1  14.633160  1.120274  1.0  14.786491
# 1     2  14.684871  0.964065  1.0  14.816822
# 2     3  14.537168  1.353890  1.0  14.722474
# 3     4  14.583595  1.204270  1.0  14.748423
# 4     5  14.803395  0.494764  1.0  14.871113

# %% [markdown]
# Now we can do all kinds of statistics, histograms, etc. for the fit parameters and the extrapolated DA

# %%
a  = davst('/home/phermes/development/SixDeskDB/chromB2_QP_2_OC_16.db')
df = a.fitda(1,10,0.5,steps=2,verbose=False)

# %%
fig = plt.figure(figsize=[12,10])
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)
ax4 = fig.add_subplot(224)

df.exda.hist(ax=ax1,bins=9)
df.d.hist(ax=ax2,bins=9)
df.b.hist(ax=ax3,bins=9)
df.k.hist(ax=ax4,bins=9)

ax1.set_xlabel(r'Extr. DA after 30 min [$\sigma$]')
ax2.set_xlabel(r'$D_\infty$')
ax3.set_xlabel(r'$b$')
ax4.set_xlabel(r'$\kappa$')
ax3.set_ylabel(r'Counts')
ax1.set_ylabel('Counts')

plt.show()

# %%
a  = davst('/home/phermes/development/SixDeskDB/chromB2_QP_4_OC_20.db')
df = a.fitda(-10,10,0.5,steps=3,verbose=False)

# %%
fig = plt.figure(figsize=[12,10])
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)
ax4 = fig.add_subplot(224)

df.exda.hist(ax=ax1,bins=9)
df.d.hist(ax=ax2,bins=9)
df.b.hist(ax=ax3,bins=9)
df.k.hist(ax=ax4,bins=9)

ax1.set_xlabel(r'Extr. DA after 30 min [$\sigma$]')
ax2.set_xlabel(r'$D_\infty$')
ax3.set_xlabel(r'$b$')
ax4.set_xlabel(r'$\kappa$')
ax3.set_ylabel(r'Counts')
ax1.set_ylabel('Counts')

plt.show()

# %%
a  = davst('/home/phermes/development/SixDeskDB/chromB2_QP_10_OC_12.db')
df = a.fitda(-10,10,0.5,steps=3,verbose=False)

# %%
fig = plt.figure(figsize=[12,10])
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)
ax4 = fig.add_subplot(224)

df.exda.hist(ax=ax1,bins=9)
df.d.hist(ax=ax2,bins=9)
df.b.hist(ax=ax3,bins=9)
df.k.hist(ax=ax4,bins=9)

ax1.set_xlabel(r'Extr. DA after 30 min [$\sigma$]')
ax2.set_xlabel(r'$D_\infty$')
ax3.set_xlabel(r'$b$')
ax4.set_xlabel(r'$\kappa$')
ax3.set_ylabel(r'Counts')
ax1.set_ylabel('Counts')

plt.show()

# %%
a  = davst('/home/phermes/development/SixDeskDB/chromB2_QP_20_OC_8.db')
df = a.fitda(-10,10,0.5,steps=3,verbose=False)

# %%
fig = plt.figure(figsize=[12,10])
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)
ax4 = fig.add_subplot(224)

df.exda.hist(ax=ax1,bins=9)
df.d.hist(ax=ax2,bins=9)
df.b.hist(ax=ax3,bins=9)
df.k.hist(ax=ax4,bins=9)

ax1.set_xlabel(r'Extr. DA after 30 min [$\sigma$]')
ax2.set_xlabel(r'$D_\infty$')
ax3.set_xlabel(r'$b$')
ax4.set_xlabel(r'$\kappa$')
ax3.set_ylabel(r'Counts')
ax1.set_ylabel('Counts')

plt.show()

# %% [markdown]
# ## Summary
#
# The examples show how, depending on the inverval of $\kappa$ that is permitted, the fitting parameters can span over a wide range of values, while the extrapolated dynamic aperture is rather confined and homogeneous.
